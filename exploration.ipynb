# %% [markdown]
# # Explore CIFAR-10 dataset

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

import matplotlib.pyplot as plt

cifar10_dataset_folder_path = 'cifar-10-batches-py'
# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %%
def get_label_string(label_num):
    return helper._load_label_names()[label_num]

# %%
#reusing helper functions to explore dataset
batch_id = 1
features_1, labels_1 = helper.load_cfar10_batch(cifar10_dataset_folder_path, batch_id)

# %%
print(type(features_1),type(labels_1))
# Out:
# <class 'numpy.ndarray'> <class 'list'>

# %%
print(features_1.shape,len(labels_1))
# Out:
# (10000, 32, 32, 3) 10000

# %%
#display first image
print(labels_1[0], get_label_string(labels_1[0]))
print(features_1[0].shape)
# print(features_1[0][:,:,0])
plt.imshow(features_1[0][:,:,2])
plt.title(get_label_string(labels_1[0]))
# Out:
# 6 frog
# (32, 32, 3)

# %%
plt.imshow(features_1[0])

# %%
helper._load_label_names()
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %%
print(helper._load_label_names()[labels_1[0]])
# Out:
# frog

# %%
#display second image
print(labels_1[1], get_label_string(labels_1[1]))
print(features_1[1].shape)
# print(features_1[1][:,:,1])
plt.imshow(features_1[1])
plt.title(get_label_string(labels_1[1]))
# Out:
# 9 truck
# (32, 32, 3)
